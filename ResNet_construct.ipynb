# %% [markdown]
# # Заголовок

# %%
import torch
import torchvision
from torch import nn
import pandas as pd
import numpy as np
import time

# %%
# hyper params
batch_size = 32
num_epoch = 100

# %% [markdown]
# ### Создаем DataLoader попутно предобрабатывая данные
# - Предварительный смотр данных можно найти в VGG_like.ipynb

# %%
from torchvision import transforms, datasets

train_transform = transforms.Compose([
        transforms.Resize((260,260)),
        transforms.RandomSizedCrop(224),
        transforms.RandomHorizontalFlip(.5),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])
test_transform = transforms.Compose([
        transforms.Resize((260,260)),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])

trainset = datasets.ImageFolder(root='../imagenette/imagenette2-320/train/', transform=train_transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True)
testset = datasets.ImageFolder(root='../imagenette/imagenette2-320/val/', transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, #batch_size=batch_size,
                                         shuffle=False)
# Out:
# /opt/conda/lib/python3.6/site-packages/torchvision/transforms/transforms.py:704: UserWarning: The use of the transforms.RandomSizedCrop transform is deprecated, please use transforms.RandomResizedCrop instead.
#   "please use transforms.RandomResizedCrop instead.")

# %% [markdown]
# ## Создаем конструктор ResNet-like сетей.
#
# ### В конструктор подается словарь с параметрами сети:
#
#  - body_input -
#  - conv_layers -
#
#  - class_qty - кол-во классов.
#  - print_dim - печатает параметры тензора на выходе из соответствующего слоя.
#
# Примеры:
# ResNet-18:
# block_qty = [2,2,2,2]
# weight_reduction = False
#
# ResNet-18:
# block_qty = [3,4,6,3]
# weight_reduction = False
#
# ResNet-50:
# block_qty = [3,4,6,3]
# weight_reduction = True
#
# ResNet-101:
# block_qty = [3,4,23,3]
# weight_reduction = True
#
# ResNet-152:
# block_qty = [3,8,36,3]
# weight_reduction = True

# %%
params = {
    'net_input': [224, 224, 3], # list height, width, channel
    'first_layer': [7, 64, 2, 3], # params of first conv_layer. [kernel_size , channel_qty, stride, padding]
    'first_maxpool': [3 ,2, 1], # params of first maxpool_layer. [kernel_size , stride, padding]
    'blocks_qty': [2,2,2,2], # list of lists. each layer should be list: qty conv layers, stride same or valid, padding
    'weight_reduction': True, # using block with less weights qty
    'class_qty': [10],
    'print_dim': True # True if you want to show how to change the tensor dimention via convolutional layers
}

# %%
def conv1x1(in_channels, out_channels):
    return nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, padding=0)

# %%
class ResNet_like(nn.Module):

    def __init__(self, params):
        self.net_input = params['net_input']
        self.first_layer = params['first_layer']
        self.first_maxpool = params['first_maxpool']
        self.blocks_qty = params['blocks_qty']
        self.class_qty = params['class_qty']
        self.weight_reduction = params['weight_reduction']
        self.print_dim = params['print_dim']
        
#         self.conv1x1 = conv1x1(*args)
#         self.batchnorm = nn.BatchNorm2d(channels)
        
        super().__init__()
        
        def block_contruct(block, no_in_block, resolution=None):
            

            self.channel_out = 16*(2**block)
            print('Input channels [in, out]: ', self.channel_in, self.channel_out)
            self.module_dict['Block_%d_%d'%(block, no_in_block)].add_module(
                        name='Block_%d_Conv_%d_1'%(block, no_in_block), 
                        module=nn.Conv2d(
                        self.channel_in,
                        self.channel_out,
                        kernel_size=3, stride=1, padding=(1,1))
                        )
            self.channel_in = self.channel_out
            self.module_dict['Block_%d_%d'%(block, no_in_block)].add_module(
                        name='Block_%d_BN_%d_1'%(block, no_in_block),
                        module=nn.BatchNorm2d(self.channel_out)
                        )
            self.module_dict['Block_%d_%d'%(block, no_in_block)].add_module(
                        name='Block_%d_Relu_%d_1'%(block, no_in_block),
                        module=nn.ReLU()
                        )
            self.module_dict['Block_%d_%d'%(block, no_in_block)].add_module(
                        name='Block_%d_Conv_%d_2'%(block, no_in_block), 
                        module=nn.Conv2d(
                        self.channel_in,
                        self.channel_out,
                        kernel_size=3, stride=1, padding=1)
                        )
            self.module_dict['Block_%d_%d'%(block, no_in_block)].add_module(
                        name='Block_%d_BN_%d_2'%(block, no_in_block),
                        module=nn.BatchNorm2d(self.channel_out)
                        )
            print('Out channels [in, out]: ', self.channel_in, self.channel_out)
      
        def reduction_block_construct(block, no_in_block, resolution=None):
                
            self.channel_out = 16*(2**block)
            self.module_dict['Block_%d_%d'%(block, no_in_block)].add_module(
                        name='Block_%d_Conv_%d_1'%(block, no_in_block), 
                        module=nn.Conv2d(
                        self.channel_in,
                        self.channel_out,
                        kernel_size=3, stride=1, padding=1)
                        )
            
            
            self.channel_in = self.channel_out
            self.module_dict['Block_%d_%d'%(block, no_in_block)].add_module(
                        name='Block_%d_BN_%d_1'%(block, no_in_block),
                        module=nn.BatchNorm2d(self.channel_out)
                        )
            self.module_dict['Block_%d_%d'%(block, no_in_block)].add_module(
                        name='Block_%d_Relu_%d_1'%(block, no_in_block),
                        module=nn.ReLU()
                        )

            self.module_dict['Block_%d_%d'%(block, no_in_block)].add_module(
                        name='Block_%d_Conv_%d_2'%(block, no_in_block), 
                        module=nn.Conv2d(
                        self.channel_in,
                        self.channel_out,
                        kernel_size=3, stride=1, padding=1)
                        )
            self.module_dict['Block_%d_%d'%(block, no_in_block)].add_module(
                        name='Block_%d_BN_%d_2'%(block, no_in_block),
                        module=nn.BatchNorm2d(self.channel_out)
                        )
            self.module_dict['Block_%d_%d'%(block, no_in_block)].add_module(
                        name='Block_%d_Relu_%d_2'%(block, no_in_block),
                        module=nn.ReLU()
                        )
            self.channel_out = 16*(2**block)*4
            self.module_dict['Block_%d_%d'%(block, no_in_block)].add_module(
                        name='Block_%d_Conv_%d_3'%(block, no_in_block), 
                        module=nn.Conv2d(
                        self.channel_in,
                        self.channel_out,
                        kernel_size=3, stride=1, padding=1)
                        )
            self.module_dict['Block_%d_%d'%(block, no_in_block)].add_module(
                        name='Block_%d_BN_%d_3'%(block, no_in_block),
                        module=nn.BatchNorm2d(self.channel_out)
                        )
            self.channel_in = self.channel_out

        
        # initial main net
        self.first = nn.Sequential()
        self.channel_in = self.net_input[2]
        self.channel_out = self.first_layer[1]
        self.resolution = np.array([self.net_input[0], self.net_input[1]])
        
        # first conv block
        self.first.add_module(name='Block_1_Conv_1_1', module=nn.Conv2d(
                        self.channel_in, 
                        self.channel_out, 
                        kernel_size=self.first_layer[0], 
                        stride=self.first_layer[2], 
                        padding=self.first_layer[3]))
        self.channel_in = self.channel_out
        self.resolution = (self.resolution - self.first_layer[0] + 1 + (self.first_layer[3] * 2)) // self.first_layer[2]
        print(self.resolution)
        self.first.add_module(name='Block_1_MaxPool_1', module=nn.MaxPool2d(
                        kernel_size=self.first_maxpool[0],
                        stride=self.first_maxpool[1],
                        padding=self.first_maxpool[2]))
        self.resolution = (self.resolution - self.first_maxpool[0] + 1 + (self.first_maxpool[2] * 2)) // self.first_maxpool[1]
        print(self.resolution)
        
        self.module_dict = nn.ModuleDict()
        
        block=2
        for block_number in self.blocks_qty:
            for no_in_block in range(block_number):
                if self.weight_reduction:
                    self.module_dict['Block_%d_%d'%(block, no_in_block+1)] = nn.Sequential()
                    reduction_block_construct(block, no_in_block+1) #params for correct layers naming
                else:
                    self.module_dict['Block_%d_%d'%(block, no_in_block+1)] = nn.Sequential()
                    block_contruct(block, no_in_block+1)  #params for correct layers naming
                # add maxpool after each block
                if no_in_block + 1 == block_number and block - 1 != len(self.blocks_qty):
                    self.resolution = self.resolution // 2
            block+=1
#         self.resolution = self.resolution * 4
        self.out = nn.Sequential()
        if self.weight_reduction:
            self.linear_input = self.resolution[0] * self.resolution[1] * (32*(2**(len(self.blocks_qty)))*4)
        else:
            self.linear_input = self.resolution[0] * self.resolution[1] * (32*(2**(len(self.blocks_qty))))
        self.out.add_module(name='output',module=nn.Linear(self.linear_input, self.class_qty[0]))
        
    def conv1x1(in_channels, out_channels):
        return nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, padding=0)

    def forward(self, x):
        x = self.first(x)
        
        block = 2
        for block_number in self.blocks_qty:
            for no_in_block in range(block_number):
                x_out = self.module_dict['Block_%d_%d' % (block, no_in_block + 1)](x)
#                 print(x.shape, x_out.shape)
                if x.shape == x_out.shape:
                    x = torch.add(x_out, x)
                else:
#                     print(x.shape, x_out.shape)
#                     print(x.device)
                    resize_weights = torch.ones([x_out.shape[1], x.shape[1], 1, 1], device=x.device)
                    resize_weights = resize_weights / (x_out.shape[1] * x.shape[1])
                    x = nn.functional.conv2d(x, resize_weights, bias=torch.zeros(x_out.shape[1],device=x.device))
                    x = torch.add(x_out, x)
                x = nn.functional.relu(x)
                # downsampling
                if no_in_block + 1 == block_number and block - 1 != len(self.blocks_qty):
                    x = nn.functional.max_pool2d(x, kernel_size=2, stride=2)
                elif no_in_block + 1 == block_number and block - 1 != len(self.blocks_qty):
#                     print(x.shape)
                    x = nn.fuctional.adaptive_avg_pool2d(x, (1, 1))
#                     print(x.shape)
#             print(torch.mean(torch.abs(x)))
            block += 1
#         print(x)
        x = x.view(x.size(0), -1)
        #         print(x.shape)
        out = self.out(x)
        #         print(out.shape)
        return out

# %% [markdown]
# Инициализируем модель с через конструктор

# %%
model = ResNet_like(params)
criterion = nn.CrossEntropyLoss()
# optimizer = torch.optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)
# Out:
# [112 112]
# [56 56]

# %% [markdown]
# Загружаем модель на видеокарту.

# %%
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
# device = 'cpu'

print(device)

model.to(device)
# Out:
# cuda:1
# ResNet_like(
#   (first): Sequential(
#     (Block_1_Conv_1_1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (Block_1_MaxPool_1): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (module_dict): ModuleDict(
#     (Block_2_1): Sequential(
#       (Block_2_Conv_1_1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_2_BN_1_1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (Block_2_Relu_1_1): ReLU()
#       (Block_2_Conv_1_2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_2_BN_1_2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (Block_2_Relu_1_2): ReLU()
#       (Block_2_Conv_1_3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_2_BN_1_3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (Block_2_2): Sequential(
#       (Block_2_Conv_2_1): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_2_BN_2_1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (Block_2_Relu_2_1): ReLU()
#       (Block_2_Conv_2_2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_2_BN_2_2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (Block_2_Relu_2_2): ReLU()
#       (Block_2_Conv_2_3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_2_BN_2_3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (Block_3_1): Sequential(
#       (Block_3_Conv_1_1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_3_BN_1_1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (Block_3_Relu_1_1): ReLU()
#       (Block_3_Conv_1_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_3_BN_1_2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (Block_3_Relu_1_2): ReLU()
#       (Block_3_Conv_1_3): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_3_BN_1_3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (Block_3_2): Sequential(
#       (Block_3_Conv_2_1): Conv2d(512, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_3_BN_2_1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (Block_3_Relu_2_1): ReLU()
#       (Block_3_Conv_2_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_3_BN_2_2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (Block_3_Relu_2_2): ReLU()
#       (Block_3_Conv_2_3): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_3_BN_2_3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (Block_4_1): Sequential(
#       (Block_4_Conv_1_1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_4_BN_1_1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (Block_4_Relu_1_1): ReLU()
#       (Block_4_Conv_1_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_4_BN_1_2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (Block_4_Relu_1_2): ReLU()
#       (Block_4_Conv_1_3): Conv2d(256, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_4_BN_1_3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (Block_4_2): Sequential(
#       (Block_4_Conv_2_1): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_4_BN_2_1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (Block_4_Relu_2_1): ReLU()
#       (Block_4_Conv_2_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_4_BN_2_2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (Block_4_Relu_2_2): ReLU()
#       (Block_4_Conv_2_3): Conv2d(256, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_4_BN_2_3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (Block_5_1): Sequential(
#       (Block_5_Conv_1_1): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_5_BN_1_1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (Block_5_Relu_1_1): ReLU()
#       (Block_5_Conv_1_2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_5_BN_1_2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (Block_5_Relu_1_2): ReLU()
#       (Block_5_Conv_1_3): Conv2d(512, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_5_BN_1_3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (Block_5_2): Sequential(
#       (Block_5_Conv_2_1): Conv2d(2048, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_5_BN_2_1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (Block_5_Relu_2_1): ReLU()
#       (Block_5_Conv_2_2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_5_BN_2_2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (Block_5_Relu_2_2): ReLU()
#       (Block_5_Conv_2_3): Conv2d(512, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (Block_5_BN_2_3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (out): Sequential(
#     (output): Linear(in_features=100352, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ## Основной тренировочный цикл и подсчет метрик.
#     Основная метрика accuracy (топ1). Очень не хотелось бы получать ошибку на топ5 accuracy при 10 классах.

# %%
for epoch in range(num_epoch):  # loop over the dataset multiple times
    
#     model.train()
    
    for i, data in enumerate(trainloader, 0):
        start_time = time.time()
        # get the inputs; data is a list of [inputs, labels]
#         inputs, labels = data
#         print(data[1])
        inputs, labels = data[0].to(device), data[1].to(device)
#         print(labels)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = model(inputs)
        loss = criterion(outputs, labels)
#         print('Loss: ', loss)
        loss.backward()
        optimizer.step()

    #Accuracy train and val
    correct_train, correct_val = 0, 0
    total_train, total_val = 0, 0
    with torch.no_grad():
        for images, labels in trainloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            outputs = outputs.to(device)
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
        for images, labels in testloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            outputs = outputs.to(device)
            _, predicted = torch.max(outputs.data, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()
    end_time = time.time()
    print("Epoch {}/{}, Time: {:.2f} sec, Loss: {:.3f}, Accuracy_train: {:.3f}, Accuracy_val: {:.3f}".
          format(epoch+1, num_epoch, end_time - start_time, loss, correct_train/total_train, correct_val/total_val))
#     print('Epoch: ', epoch, ' loss:', loss[0], ' accuracy_val: ', accuracy(outputs, labels))

       
        # print statistics
#         running_loss += loss.item()
#         if i % 10 == 9:    # print every 2000 mini-batches
#             print('[%d, %5d] loss: %.3f' %
#                   (epoch + 1, i + 1, loss)) #running_loss / 2000
#             print('labels:',  labels)
#             print('outputs: ', outputs)
#             running_loss = 0.0

print('Finished Training')
# Out:
# Epoch 1/100, Time: 85.94 sec, Loss: 26.124, Accuracy_train: 0.101, Accuracy_val: 0.102
# Epoch 2/100, Time: 88.66 sec, Loss: 22.479, Accuracy_train: 0.115, Accuracy_val: 0.099
# Epoch 3/100, Time: 86.45 sec, Loss: 0.000, Accuracy_train: 0.136, Accuracy_val: 0.099
# Epoch 4/100, Time: 85.99 sec, Loss: 125.796, Accuracy_train: 0.148, Accuracy_val: 0.108
# Epoch 5/100, Time: 85.89 sec, Loss: 596.742, Accuracy_train: 0.132, Accuracy_val: 0.100
# Epoch 6/100, Time: 85.97 sec, Loss: 68.072, Accuracy_train: 0.097, Accuracy_val: 0.098
# Epoch 7/100, Time: 85.94 sec, Loss: 177.602, Accuracy_train: 0.116, Accuracy_val: 0.102
# Epoch 8/100, Time: 86.22 sec, Loss: 121.302, Accuracy_train: 0.135, Accuracy_val: 0.109
# Epoch 9/100, Time: 86.23 sec, Loss: 81.301, Accuracy_train: 0.140, Accuracy_val: 0.103
# Epoch 10/100, Time: 86.08 sec, Loss: 5.536, Accuracy_train: 0.153, Accuracy_val: 0.094
# Epoch 11/100, Time: 86.08 sec, Loss: 18.341, Accuracy_train: 0.166, Accuracy_val: 0.099
# Epoch 12/100, Time: 86.07 sec, Loss: 2.564, Accuracy_train: 0.181, Accuracy_val: 0.112
# Epoch 13/100, Time: 86.19 sec, Loss: 2.215, Accuracy_train: 0.203, Accuracy_val: 0.113
# Epoch 14/100, Time: 85.93 sec, Loss: 30.625, Accuracy_train: 0.223, Accuracy_val: 0.125
# Epoch 15/100, Time: 85.95 sec, Loss: 1.532, Accuracy_train: 0.251, Accuracy_val: 0.136
# Epoch 16/100, Time: 86.15 sec, Loss: 4.647, Accuracy_train: 0.268, Accuracy_val: 0.145
# Epoch 17/100, Time: 88.68 sec, Loss: 67.777, Accuracy_train: 0.173, Accuracy_val: 0.111
# Epoch 18/100, Time: 86.10 sec, Loss: 38.088, Accuracy_train: 0.212, Accuracy_val: 0.111
# Epoch 19/100, Time: 86.20 sec, Loss: 2.045, Accuracy_train: 0.222, Accuracy_val: 0.136
# Epoch 20/100, Time: 86.04 sec, Loss: 1.692, Accuracy_train: 0.247, Accuracy_val: 0.120
# Epoch 21/100, Time: 85.88 sec, Loss: 2.804, Accuracy_train: 0.253, Accuracy_val: 0.128
# Epoch 22/100, Time: 86.08 sec, Loss: 3.157, Accuracy_train: 0.263, Accuracy_val: 0.129
# Epoch 23/100, Time: 86.04 sec, Loss: 2.346, Accuracy_train: 0.292, Accuracy_val: 0.141
# Epoch 24/100, Time: 85.86 sec, Loss: 3.661, Accuracy_train: 0.302, Accuracy_val: 0.142
# Epoch 25/100, Time: 85.93 sec, Loss: 1.335, Accuracy_train: 0.321, Accuracy_val: 0.158
# Epoch 26/100, Time: 85.88 sec, Loss: 1.756, Accuracy_train: 0.290, Accuracy_val: 0.141
# Epoch 27/100, Time: 85.80 sec, Loss: 2.726, Accuracy_train: 0.303, Accuracy_val: 0.153
# Epoch 28/100, Time: 85.90 sec, Loss: 0.967, Accuracy_train: 0.297, Accuracy_val: 0.156
# Epoch 29/100, Time: 85.85 sec, Loss: 17.549, Accuracy_train: 0.244, Accuracy_val: 0.174
# Epoch 30/100, Time: 85.85 sec, Loss: 3.641, Accuracy_train: 0.274, Accuracy_val: 0.142
# Epoch 31/100, Time: 86.17 sec, Loss: 1.759, Accuracy_train: 0.295, Accuracy_val: 0.130
# Epoch 32/100, Time: 86.26 sec, Loss: 1.030, Accuracy_train: 0.310, Accuracy_val: 0.165
# Epoch 33/100, Time: 86.28 sec, Loss: 1.733, Accuracy_train: 0.320, Accuracy_val: 0.182
# Epoch 34/100, Time: 86.13 sec, Loss: 2.454, Accuracy_train: 0.352, Accuracy_val: 0.178
